# %% [markdown]
# ![image.png](attachment:f044adb7-69fb-48c5-9ce5-8165472a867e.png)

# %%
# Out:
# Purchases of Sara:
# yogurt
# chips
# New list for Ali:
# milk
# bread
# juice
# Common items between Ali and Reza:
# milk
# Sara wants to buy 2 items.

# %% [markdown]
# ![image.png](attachment:a63616e2-4fbf-459c-9547-29f647c04ff6.png)

# %%
# Out:
# Mina's classes:
# literature
# math
# All unique classes:
# math
# science
# literature
# art
# Common classes between Reza and Mina:
# math
# Unique classes for Hassan:
# art

# %% [markdown]
# ![image.png](attachment:4c2b4e3f-8bcf-42ce-9a74-c38e3888b669.png)

# %%
# Out:
# Sara's items:
# phone
# glasses
# New items for Hassan:
# book
# camera
# water
# People who have a camera:
# Hassan
# Ali
# Number of people with camera: 2
